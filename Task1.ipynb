# %% [markdown]
# <a href="https://colab.research.google.com/github/akshay3144/Perform_Data_Cleaning/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install jovian --upgrade --q
import jovian
jovian.set_project('new')
jovian.set_colab_id('1vrLH8BhzAmhSCeNFLMcZi3rR_zkTnXng')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od
# {"username":"akshaybajbalkar","key":"692ce671402c0e3bfb67aa4f0181ec9a"}
download_url='https://www.kaggle.com/competitions/titanic/data?select=train.csv'
od.download(download_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: akshaybajbalkar
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 34.1k/34.1k [00:00<00:00, 6.05MB/s]
# Extracting archive ./titanic/titanic.zip to ./titanic

# %%
import pandas as pd

# %%
data_filename1='/content/titanic/train.csv'

# %%
df1=pd.read_csv(data_filename1)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# TASK 1 :- Perform Data Cleaning

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# to get percentage of value missing in dataset

# %%
null_var=df1.isnull().sum()/df1.shape[0]*100
null_var
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
todrop=null_var[null_var>50]
todrop
# Out:
# Cabin    77.104377
# dtype: float64

# %% [markdown]
# AS THE PERCENTAGE OF MISSING VALUE IS MORE IN THE CABIN COLUMN AND IT IS OF NO USE FOR ANALYSIS WE DROP THE COLUMN OF CABIN AND EMBARKED

# %%
df2=df1.drop(labels=['Cabin','Embarked'], axis=1)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Now Replaceing Missing Value In Age Column with the Mean Value Of Age

# %%
df4=df2['Age'] = df2['Age'].fillna(meanage)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %% [markdown]
# Therefore Their is No Missing Value In The Data Set
