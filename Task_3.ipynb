# %% [markdown]
# <a href="https://colab.research.google.com/github/akshay3144/TechnoHack_Internship/blob/Task-3/Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install jovian --upgrade --q
import jovian
jovian.set_project('new')
jovian.set_colab_id('1vrLH8BhzAmhSCeNFLMcZi3rR_zkTnXng')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od
download_url='https://www.kaggle.com/competitions/titanic/data?select=train.csv'
od.download(download_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: akshaybajbalkar
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 34.1k/34.1k [00:00<00:00, 13.7MB/s]
# Extracting archive ./titanic/titanic.zip to ./titanic

# %%
import pandas as pd

# %%
data_filename1='/content/titanic/train.csv'

# %%
df1=pd.read_csv(data_filename1)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#TASK 3 :- Create Histogram or bar chart

# %%
import matplotlib.pyplot as mp

# %%
df2=df1.iloc[400:430,1:12]
df2
# Out:
#      Survived  Pclass                                               Name  \
# 400         1       3                                 Niskanen, Mr. Juha
# 401         0       3                                    Adams, Mr. John
# 402         0       3                           Jussila, Miss. Mari Aina
# 403         0       3                     Hakkarainen, Mr. Pekka Pietari
# 404         0       3                            Oreskovic, Miss. Marija
# 405         0       2                                 Gale, Mr. Shadrach
# 406         0       3                   Widegren, Mr. Carl/Charles Peter
# 407         1       2                     Richards, Master. William Rowe
# 408         0       3                  Birkeland, Mr. Hans Martin Monsen
# 409         0       3                                 Lefebre, Miss. Ida
# 410         0       3                                 Sdycoff, Mr. Todor
# 411         0       3                                    Hart, Mr. Henry
# ...

# %%
meanage=df2["Age"].mean().astype(int)
meanage
# Out:
# 26

# %%
df4=df2['Age'] = df2['Age'].fillna(meanage)
df4

# %% [markdown]
# Let Check Whether The Fare was dependent on the Sex and Age

# %%
df2.plot(x="Sex", y=["Fare","Age"], kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# So From above bar graph we can Say That the fare for the trip was independent of sex and Age

# %% [markdown]
# Now Let Check Whether safety board was given based on sex or not

# %%
df2.plot(x="Sex", y="Survived", kind="bar")
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# So from above bar graph we can say that both male and female got equal chance to survived

# %%
df4.plot(x="Age", y="Survived", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# So The Above Histogram show that how much people of particuler age survived
